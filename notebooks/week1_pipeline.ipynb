# %%
import pandas as pd

df = pd.read_csv("../data/amazon_reviews.csv")

print(df.shape)
print(df.columns)
df.head()
# Out:
# (568454, 10)
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# ...

# %%
df = pd.read_csv("../data/cleaned_amazon_reviews.csv")

print(df.shape)
print(df.head())
# Out:
# (200000, 13)
#        Id  product_id          UserId                        ProfileName  \
# 0  157621  B0015AT546   ASJT08B3X5FIK                 Stanley E. Kessler
# 1  300783  B002R8UANK   AVEHS8PMSVYJ1                           Kristine
# 2   36329  B002KAL1B0   A69BR2RCF9MV1                             Lana M
# 3    2995  B0009JI7O8   A2V46U8E1DKLA           Kia Kat "Crazy Cat Lady"
# 4  377679  B000PKL5WC  A34Y6BATEPO9RL  Claudette Shepherd "nubien sense"
#
#    helpful_votes  HelpfulnessDenominator  rating   timestamp  \
# 0              0                       0       5  2012-09-03
# 1              2                       2       5  2012-05-08
# 2              0                       0       5  2010-04-06
# 3              4                       4       4  2007-12-22
# 4              0                       1       5  2010-05-09
#
#                                Summary  \
# 0                 good find good price
# 1  Frantastic grain free doggie treats
# ...
